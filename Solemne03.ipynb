# %%
import pandas as pd
import matplotlib

df = pd.read_csv("Solemne03.csv", index_col="ID")
df
# Out:
#      Nombres  Edad  Sueldo
# ID
# 1       Juan    54   69472
# 2       Juan    35   72051
# 3       Juan   165   86028
# 4       Juan    84  124490
# 5       Juan   132    3916
# ...      ...   ...     ...
# 2138   Pedro    58  190447
# 2139   Pedro    33   33844
# 2140   Pedro   134  165366
# 2141    TRUE     1       1
# 2142   FALSE     0       0
#
# [2142 rows x 3 columns]

# %%
df["Nombres"]
c_df = df.drop_duplicates(subset="Nombres")
c_df

c_df[(c_df["Edad"]<120) & (c_df["Edad"]>2)]
# Out:
#         Nombres  Edad  Sueldo
# ID
# 1          Juan    54   69472
# 511      Ximena    63   64209
# 715    Macarena    76  110422
# 919     Antonia    98  182524
# 1123     Magnus    84   94671
# 1225        Ana    22   17561
# 1429    Rodrigo    69  123139
# 1531     Manuel    32   28292
# 1633     Leonor    98  103221
# 1735  Anastasia   119   88373
# 1837       Luis   100  189536

# %%
import random

def Random():
    n=random.randint(1,2)

def DocEst():
    if Random()==1:
        return "Docente"
    elif Random()==2:
        return "Estudiante"

c1df = c_df["Tipo"]=c_df.apply(DocEst, axis=1)
c1df()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 10
#       7     elif indice==2:
#       8         return "Estudiante"
# ---> 10 c1df = c_df["Tipo"]=c_df.apply(DocEst, axis=1)
#      11 c1df()
#
# File c:\Users\nck7e\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\nck7e\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# ...
